# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# importing required packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
# reading the dataset and loading into a dataframe
df = pd.read_csv('../../data/data.csv')

df.head()
# Out:
#                                             Sentence Sentiment
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral

# %%
# printing the shape: (rows, columns)
df.shape
# Out:
# (5842, 2)

# %%
# distribution of datapoints into respective class labels
print(df['Sentiment'].value_counts())

# plotting the class distribution after droping duplicates
chart = sns.countplot(x="Sentiment", data=df, palette="Set2")
axes = chart.axes
axes.set_title('Class Distribution')
axes.set_xlabel('Sentiment')
plt.show()
# Out:
# neutral     3130
# positive    1852
# negative     860
# Name: Sentiment, dtype: int64

# %%
# finding duplicate sentences
df[df['Sentence'].duplicated()]
# Out:
#                                                Sentence Sentiment
# 266   Finnish GeoSentric 's net sales decreased to E...   neutral
# 283   Sales in Finland decreased by 10.5 % in Januar...  negative
# 349   Full-year operating result for 2008 was 3.6 mi...  negative
# 387   Making matters more difficult , the company sa...  negative
# 496   Antti Orkola , president of Kemira GrowHow 's ...  negative
# ...                                                 ...       ...
# 5827  ( ADPnews ) - Oct 21 , 2009 - Finland-based IT...  negative
# 5831  Finnish developer and manufacturer of mobile p...  negative
# 5832  Operating profit fell to EUR 38.1 mn from EUR ...  negative
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5840  In the building and home improvement trade , s...   neutral
#
# [520 rows x 2 columns]

# %%
# extracting indices of duplicate sentences
duplicate_indices = df[df['Sentence'].duplicated()].index.to_list()

# printing each set of duplicate sentences
for index in duplicate_indices:
    print(df[df['Sentence'] == df['Sentence'].loc[index]])
    print()
# Out:
#                                               Sentence Sentiment
# 66   Finnish GeoSentric 's net sales decreased to E...  negative
# 266  Finnish GeoSentric 's net sales decreased to E...   neutral
#
#                                               Sentence Sentiment
# 163  Sales in Finland decreased by 10.5 % in Januar...   neutral
# 283  Sales in Finland decreased by 10.5 % in Januar...  negative
#
#                                               Sentence Sentiment
# 195  Full-year operating result for 2008 was 3.6 mi...   neutral
# 349  Full-year operating result for 2008 was 3.6 mi...  negative
#
#                                               Sentence Sentiment
# 169  Making matters more difficult , the company sa...   neutral
# 387  Making matters more difficult , the company sa...  negative
#
#                                               Sentence Sentiment
# 201  Antti Orkola , president of Kemira GrowHow 's ...   neutral
# 496  Antti Orkola , president of Kemira GrowHow 's ...  negative
#
#                                               Sentence Sentiment
# 101  At 12.59 pm , the OMX Helsinki 25 index was 0....  negative
# 509  At 12.59 pm , the OMX Helsinki 25 index was 0....   neutral
#
#                                               Sentence Sentiment
# 403  Comparable operating profit totaled EUR 4.7 mn...  negative
# 525  Comparable operating profit totaled EUR 4.7 mn...   neutral
#
#                                               Sentence Sentiment
# 512  Revenue was slightly down , at  x20ac 495 mill...   neutral
# 579  Revenue was slightly down , at  x20ac 495 mill...  negative
#
#                                               Sentence Sentiment
# 384  The maritime administration said the ships had...  negative
# 751  The maritime administration said the ships had...   neutral
#
#                                               Sentence Sentiment
# 624  Finnish forest machinery manufacturer Ponsse h...  negative
# 828  Finnish forest machinery manufacturer Ponsse h...   neutral
#
#                                               Sentence Sentiment
# 806  ( ADPnews ) - Feb 3 , 2010 - Finland-based ste...   neutral
# 855  ( ADPnews ) - Feb 3 , 2010 - Finland-based ste...  negative
#
#                                               Sentence Sentiment
# 851  Operating profits in the half were  0.8 m , do...  negative
# 882  Operating profits in the half were  0.8 m , do...   neutral
#
#                                               Sentence Sentiment
# 332  External net sales from the printing business ...   neutral
# 897  External net sales from the printing business ...  negative
#
#                                               Sentence Sentiment
# 289  Danish company FLSmidth has acknowledged that ...   neutral
# 915  Danish company FLSmidth has acknowledged that ...  negative
#
#                                               Sentence Sentiment
# 466  Earnings per share ( EPS ) dropped to EUR 0.21...   neutral
# 959  Earnings per share ( EPS ) dropped to EUR 0.21...  negative
#
#                                               Sentence Sentiment
# 631  However , the company saw its net profit for t...   neutral
# 967  However , the company saw its net profit for t...  negative
#
#                                      Sentence Sentiment
# 13   Viking Line has canceled some services .   neutral
# 976  Viking Line has canceled some services .  negative
#
#                                               Sentence Sentiment
# 139  Finnish insurance company Fennia and Kesko Gro...   neutral
# 984  Finnish insurance company Fennia and Kesko Gro...  negative
#
#                                               Sentence Sentiment
# 125  The operating margin of Aker Yards Cruise & Fe...  negative
# 996  The operating margin of Aker Yards Cruise & Fe...   neutral
#
#                                                Sentence Sentiment
# 131   Temporary lay-offs , affecting the entire work...  negative
# 1011  Temporary lay-offs , affecting the entire work...   neutral
#
#                                                Sentence Sentiment
# 601   Finnish electronics manufacturing services EMS...   neutral
# 1016  Finnish electronics manufacturing services EMS...  negative
#
#                                                Sentence Sentiment
# 382   Cash Flow from Operations for the most recent ...   neutral
# 1029  Cash Flow from Operations for the most recent ...  negative
#
#                                                Sentence Sentiment
# 80    Changes in the market situation and tougher pr...  negative
# 1050  Changes in the market situation and tougher pr...   neutral
#
#                                                Sentence Sentiment
# 740   ( ADP News ) - Feb 4 , 2009 - Finnish broadban...   neutral
# 1051  ( ADP News ) - Feb 4 , 2009 - Finnish broadban...  negative
#
#                                                Sentence Sentiment
# 562   Operating profit was EUR 1.6 mn in 2005 compar...  negative
# 1061  Operating profit was EUR 1.6 mn in 2005 compar...   neutral
#
#                                                Sentence Sentiment
# 238   17 March 2011 - Goldman Sachs estimates that t...  negative
# 1100  17 March 2011 - Goldman Sachs estimates that t...   neutral
#
#                                                Sentence Sentiment
# 362   Operating profit in the fourth quarter fell to...   neutral
# 1141  Operating profit in the fourth quarter fell to...  negative
#
#                                                Sentence Sentiment
# 99    The liquidity providing was interrupted on May...   neutral
# 1157  The liquidity providing was interrupted on May...  negative
#
#                                                Sentence Sentiment
# 73    Finnish IT solutions provider Affecto Oyj HEL ...   neutral
# 1206  Finnish IT solutions provider Affecto Oyj HEL ...  negative
#
#                                                Sentence Sentiment
# 948   The announcement pushed Freenet shares down 6....  negative
# 1237  The announcement pushed Freenet shares down 6....   neutral
#
#                                                Sentence Sentiment
# 997   HELSINKI Thomson Financial - Shares in Cargote...  negative
# 1320  HELSINKI Thomson Financial - Shares in Cargote...   neutral
#
#                                                Sentence Sentiment
# 1258  The air traffic of Finland has been in stoppag...  negative
# 1336  The air traffic of Finland has been in stoppag...   neutral
#
#                                                Sentence Sentiment
# 1117  Therefore , the company 's 2005 result will re...   neutral
# 1349  Therefore , the company 's 2005 result will re...  negative
#
#                                                Sentence Sentiment
# 886   Relations with the City have been further dama...  negative
# 1353  Relations with the City have been further dama...   neutral
#
#                                                Sentence Sentiment
# 908   Operating profit , excluding non-recurring ite...  negative
# 1365  Operating profit , excluding non-recurring ite...   neutral
#
#                                                Sentence Sentiment
# 982   Finnish plumbing and heating systems supplier ...   neutral
# 1393  Finnish plumbing and heating systems supplier ...  negative
#
#                                                Sentence Sentiment
# 1111  Finnish Kemira 's net sales EUR decreased to E...   neutral
# 1408  Finnish Kemira 's net sales EUR decreased to E...  negative
#
#                                                Sentence Sentiment
# 1092  Profit before taxes was EUR 4.0 mn , down from...   neutral
# 1457  Profit before taxes was EUR 4.0 mn , down from...  negative
#
#                                                Sentence Sentiment
# 405   ( ADPnews ) - May 4 , 2010 - Finnish cutlery a...   neutral
# 1464  ( ADPnews ) - May 4 , 2010 - Finnish cutlery a...  negative
#
#                                                Sentence Sentiment
# 1422  In a media advisory , the NTSB said that after...   neutral
# 1492  In a media advisory , the NTSB said that after...  negative
#
#                                                Sentence Sentiment
# 109   Finnish Exel Composites , a technology company...   neutral
# 1516  Finnish Exel Composites , a technology company...  negative
#
#                                                Sentence Sentiment
# 1247  National Conciliator Juhani Salonius , who met...  negative
# 1517  National Conciliator Juhani Salonius , who met...   neutral
#
#                                                Sentence Sentiment
# 206   Operating profit totalled EUR 30.2 mn , down f...   neutral
# 1550  Operating profit totalled EUR 30.2 mn , down f...  negative
#
#                                                Sentence Sentiment
# 217   Operating result for the 12-month period decre...   neutral
# 1559  Operating result for the 12-month period decre...  negative
#
#                                                Sentence Sentiment
# 1366  `` However , the rapidly increasing costs and ...   neutral
# 1566  `` However , the rapidly increasing costs and ...  negative
#
#                                                Sentence Sentiment
# 1296  In Finland , OP-Pohjola 's staff union is boyc...  negative
# 1573  In Finland , OP-Pohjola 's staff union is boyc...   neutral
#
#                                                Sentence Sentiment
# 491   ( ADPnews ) - Dec 1 , 2009 - Finnish cutlery a...  negative
# 1581  ( ADPnews ) - Dec 1 , 2009 - Finnish cutlery a...   neutral
#
#                                                Sentence Sentiment
# 487   ArcelorMittal Chief Executive Officer Lakshmi ...   neutral
# 1631  ArcelorMittal Chief Executive Officer Lakshmi ...  negative
#
#                                                Sentence Sentiment
# 1369  Rapala VMC Corporation STOCK EXCHANGE RELEASE ...  negative
# 1710  Rapala VMC Corporation STOCK EXCHANGE RELEASE ...   neutral
#
#                                                Sentence Sentiment
# 1022  Finnair 's total traffic decreased by 8.7 % in...   neutral
# 1715  Finnair 's total traffic decreased by 8.7 % in...  negative
#
#                                                Sentence Sentiment
# 57    Diluted earnings per share ( EPS ) fell to EUR...   neutral
# 1727  Diluted earnings per share ( EPS ) fell to EUR...  negative
#
#                                                Sentence Sentiment
# 826   Operating profit margin was 8.3 % , compared t...  negative
# 1797  Operating profit margin was 8.3 % , compared t...   neutral
#
#                                                Sentence Sentiment
# 1770  Net profit fell by almost half to +é 5.5 milli...   neutral
# 1799  Net profit fell by almost half to +é 5.5 milli...  negative
#
#                                                Sentence Sentiment
# 1367  Net profit in the three months through March 3...   neutral
# 1822  Net profit in the three months through March 3...  negative
#
#                                                Sentence Sentiment
# 629   Proha Plc ( Euronext :7327 ) announced today (...   neutral
# 1825  Proha Plc ( Euronext :7327 ) announced today (...   neutral
#
#                                                Sentence Sentiment
# 817   Operating margin , however , slipped to 14.4 %...   neutral
# 1831  Operating margin , however , slipped to 14.4 %...  negative
#
#                                                Sentence Sentiment
# 41    Dolce & Gabbana has asked the European Union t...  negative
# 1833  Dolce & Gabbana has asked the European Union t...   neutral
#
#                                                Sentence Sentiment
# 815   SSH Communications Security Corporation is hea...   neutral
# 1859  SSH Communications Security Corporation is hea...   neutral
#
#                                                Sentence Sentiment
# 77    Operating profit fell to EUR 20.3 mn from EUR ...   neutral
# 1880  Operating profit fell to EUR 20.3 mn from EUR ...  negative
#
#                                                Sentence Sentiment
# 583   The sale will result in a capital loss of EUR5...   neutral
# 1889  The sale will result in a capital loss of EUR5...  negative
#
#                                                Sentence Sentiment
# 1065  Finland-based Stockmann Group has closed seven...  negative
# 1927  Finland-based Stockmann Group has closed seven...   neutral
#
#                                                Sentence Sentiment
# 480   In January-November 2009 , the group 's sales ...  negative
# 1929  In January-November 2009 , the group 's sales ...   neutral
#
#                                                Sentence Sentiment
# 449   Finnish airline Finnair is starting the tempor...   neutral
# 1950  Finnish airline Finnair is starting the tempor...  negative
#
#                                                Sentence Sentiment
# 75    Profit for the period was EUR 10.9 mn , down f...   neutral
# 1964  Profit for the period was EUR 10.9 mn , down f...  negative
#
#                                                Sentence Sentiment
# 1162  In the fourth quarter of 2008 , net sales decr...   neutral
# 2020  In the fourth quarter of 2008 , net sales decr...  negative
#
#                                                Sentence Sentiment
# 1963  Tallink Silja attributes the significant drop ...  negative
# 2034  Tallink Silja attributes the significant drop ...   neutral
#
#                                                Sentence Sentiment
# 721   Finnish laboratory liquid handling and diagnos...   neutral
# 2047  Finnish laboratory liquid handling and diagnos...  negative
#
#                                                Sentence Sentiment
# 1222  Device volume in the area decreased by 21 % to...   neutral
# 2069  Device volume in the area decreased by 21 % to...  negative
#
#                                                Sentence Sentiment
# 570   Operating profit decreased to EUR 11.2 mn from...  negative
# 2078  Operating profit decreased to EUR 11.2 mn from...   neutral
#
#                                                Sentence Sentiment
# 1699  The workforce will be reduced also in the Amst...   neutral
# 2080  The workforce will be reduced also in the Amst...  negative
#
#                                                Sentence Sentiment
# 1668  Operating profit fell from EUR 7.9 mn in the s...  negative
# 2107  Operating profit fell from EUR 7.9 mn in the s...   neutral
#
#                                                Sentence Sentiment
# 1685  Operating profit excluding non-recurring items...  negative
# 2159  Operating profit excluding non-recurring items...   neutral
#
#                                                Sentence Sentiment
# 1426  Tornio Works employs 2,300 of whom more than 1...   neutral
# 2161  Tornio Works employs 2,300 of whom more than 1...  negative
#
#                                                Sentence Sentiment
# 2057  The company confirmed its estimate for lower r...   neutral
# 2206  The company confirmed its estimate for lower r...  negative
#
#                                                Sentence Sentiment
# 991   Operating profit for 2009 lower than outlook p...   neutral
# 2210  Operating profit for 2009 lower than outlook p...  negative
#
#                                                Sentence Sentiment
# 1660  Stora Enso Oyj said its second-quarter result ...   neutral
# 2213  Stora Enso Oyj said its second-quarter result ...  negative
#
#                                                Sentence Sentiment
# 2135  Currently , the company foresees its pre-tax p...   neutral
# 2233  Currently , the company foresees its pre-tax p...  negative
#
#                                                Sentence Sentiment
# 1033  In October , UPM reported a third-quarter net ...   neutral
# 2244  In October , UPM reported a third-quarter net ...  negative
#
#                                                Sentence Sentiment
# 1884  The company confirmed its estimate for lower r...  negative
# 2254  The company confirmed its estimate for lower r...   neutral
#
#                                                Sentence Sentiment
# 259   Pretax loss totaled EUR 117mn compared to a lo...   neutral
# 2272  Pretax loss totaled EUR 117mn compared to a lo...  negative
#
#                                                Sentence Sentiment
# 1244  Pretax loss totalled EUR 162.3 mn compared to ...   neutral
# 2282  Pretax loss totalled EUR 162.3 mn compared to ...  negative
#
#                                                Sentence Sentiment
# 622   Net sales have been eaten by the weak US dollar .  negative
# 2283  Net sales have been eaten by the weak US dollar .   neutral
#
#                                                Sentence Sentiment
# 1865  Border Guard Service has banned the mooring of...  negative
# 2287  Border Guard Service has banned the mooring of...   neutral
#
#                                       Sentence Sentiment
# 1133  Asian traffic declined by 3.4 per cent .   neutral
# 2288  Asian traffic declined by 3.4 per cent .  negative
#
#                                                Sentence Sentiment
# 841   Finnish metal products company Componenta Oyj ...   neutral
# 2296  Finnish metal products company Componenta Oyj ...  negative
#
#                                                Sentence Sentiment
# 2092  Operating loss amounted to EUR 0.9 mn in the f...  negative
# 2301  Operating loss amounted to EUR 0.9 mn in the f...   neutral
#
#                                                Sentence Sentiment
# 69    Paper companies were in negative territories ,...   neutral
# 2325  Paper companies were in negative territories ,...  negative
#
#                                                Sentence Sentiment
# 2279  Kiosk and cinema operations have suffered , in...  negative
# 2328  Kiosk and cinema operations have suffered , in...   neutral
#
#                                                Sentence Sentiment
# 2327  The OMX Helsinki index was down 0.34 pct at 8,...  negative
# 2342  The OMX Helsinki index was down 0.34 pct at 8,...   neutral
#
#                                                Sentence Sentiment
# 705   The total headcount reduction will be 50 perso...  negative
# 2345  The total headcount reduction will be 50 perso...   neutral
#
#                                                Sentence Sentiment
# 1583  The sales of the Tiimari segment fell by 4.0 %...  negative
# 2350  The sales of the Tiimari segment fell by 4.0 %...   neutral
#
#                                                Sentence Sentiment
# 874   Initially , the company said a maximum of 15 p...   neutral
# 2369  Initially , the company said a maximum of 15 p...  negative
#
#                                                Sentence Sentiment
# 102   The decision means temporary lay-offs of fixed...   neutral
# 2375  The decision means temporary lay-offs of fixed...  negative
#
#                                                Sentence Sentiment
# 1465  Frost sold shares for $ 19 million at $ 6.06-7...   neutral
# 2398  Frost sold shares for $ 19 million at $ 6.06-7...  negative
#
#                                                Sentence Sentiment
# 2249  Operating profit for the nine-month period dec...   neutral
# 2416  Operating profit for the nine-month period dec...  negative
#
#                                                Sentence Sentiment
# 1080  Biohit said that it will reduce the number of ...   neutral
# 2440  Biohit said that it will reduce the number of ...  negative
#
#                                                Sentence Sentiment
# 123   The OMX Nordic 40 OMXN40 index , comprising th...  negative
# 2442  The OMX Nordic 40 OMXN40 index , comprising th...   neutral
#
#                                                Sentence Sentiment
# 1525  Operating result showed a loss of EUR 2.9 mn ,...  negative
# 2459  Operating result showed a loss of EUR 2.9 mn ,...   neutral
#
#                                                Sentence Sentiment
# 2252  Operating loss before non-recurring items was ...   neutral
# 2460  Operating loss before non-recurring items was ...  negative
#
#                                                Sentence Sentiment
# 226   And U.S. energy executives say high steel pric...  negative
# 2464  And U.S. energy executives say high steel pric...   neutral
#
#                                                Sentence Sentiment
# 558   The announcement comes two weeks before a key ...   neutral
# 2484  The announcement comes two weeks before a key ...  negative
#
#                                                Sentence Sentiment
# 1238  At 10.33 am , Huhtamaki was the market 's bigg...  negative
# 2488  At 10.33 am , Huhtamaki was the market 's bigg...   neutral
#
#                                                Sentence Sentiment
# 1921  Also construction expenses have gone up in Rus...  negative
# 2495  Also construction expenses have gone up in Rus...   neutral
#
#                                                Sentence Sentiment
# 1848  Prices and delivery volumes of broadband produ...   neutral
# 2557  Prices and delivery volumes of broadband produ...  negative
#
#                                                Sentence Sentiment
# 1988  `` There 's the issue of thieves stealing them...   neutral
# 2560  `` There 's the issue of thieves stealing them...  negative
#
#                                                Sentence Sentiment
# 1556  Earlier today , Geberit 's Finnish rival Upono...  negative
# 2597  Earlier today , Geberit 's Finnish rival Upono...   neutral
#
#                                                Sentence Sentiment
# 635   Net sales decreased to EUR 91.6 mn from EUR 10...  negative
# 2609  Net sales decreased to EUR 91.6 mn from EUR 10...   neutral
#
#                                                Sentence Sentiment
# 1503  Operating profit was EUR -0.1 mn , down from E...   neutral
# 2617  Operating profit was EUR -0.1 mn , down from E...  negative
#
#                                                Sentence Sentiment
# 1071  As part of the reorganisation measures that wi...   neutral
# 2618  As part of the reorganisation measures that wi...  negative
#
#                                                Sentence Sentiment
# 458   As capacity was cut with 1.4 % , the passenger...  negative
# 2620  As capacity was cut with 1.4 % , the passenger...   neutral
#
#                                                Sentence Sentiment
# 1036  YIT 's Baltic sales in the first three quarter...   neutral
# 2622  YIT 's Baltic sales in the first three quarter...  negative
#
#                                                Sentence Sentiment
# 316   ADP News - Feb 13 , 2009 - Finnish retailer Ke...  negative
# 2627  ADP News - Feb 13 , 2009 - Finnish retailer Ke...   neutral
#
#                                                Sentence Sentiment
# 2133  The operating loss amounted to EUR 0.8 mn , co...   neutral
# 2641  The operating loss amounted to EUR 0.8 mn , co...  negative
#
#                                                Sentence Sentiment
# 2234  Ahlstrom 's share is quoted on the NASDAQ OMX ...   neutral
# 2672  Ahlstrom 's share is quoted on the NASDAQ OMX ...   neutral
#
#                                                Sentence Sentiment
# 2070  - Demand for fireplace products was lower than...   neutral
# 2674  - Demand for fireplace products was lower than...  negative
#
#                                                Sentence Sentiment
# 2675  Net sales of Kyro 's main business area , Glas...   neutral
# 2696  Net sales of Kyro 's main business area , Glas...  negative
#
#                                                Sentence Sentiment
# 1932  `` Uncommonly weak snow conditions in nearly e...  negative
# 2699  `` Uncommonly weak snow conditions in nearly e...   neutral
#
#                                                Sentence Sentiment
# 749   The company 's profit before taxes fell to EUR...   neutral
# 2701  The company 's profit before taxes fell to EUR...  negative
#
#                                                Sentence Sentiment
# 987   In Q1 of 2009 , Bank of +àland 's net interest...   neutral
# 2708  In Q1 of 2009 , Bank of +àland 's net interest...  negative
#
#                                                Sentence Sentiment
# 1666  TeliaSonera 's underlying results however incl...  negative
# 2719  TeliaSonera 's underlying results however incl...   neutral
#
#                                                Sentence Sentiment
# 200   A survey conducted by Taloustutkimus for Sampo...   neutral
# 2726  A survey conducted by Taloustutkimus for Sampo...  negative
#
#                                                Sentence Sentiment
# 1505  Earnings per share ( EPS ) amounted to a loss ...   neutral
# 2769  Earnings per share ( EPS ) amounted to a loss ...  negative
#
#                                                Sentence Sentiment
# 235   The move was triggered by weak demand for fore...  negative
# 2775  The move was triggered by weak demand for fore...   neutral
#
#                                                Sentence Sentiment
# 1180  As a result , the company will temporarily lay...  negative
# 2779  As a result , the company will temporarily lay...   neutral
#
#                                                Sentence Sentiment
# 425   In addition , a further 29 employees can be la...   neutral
# 2821  In addition , a further 29 employees can be la...  negative
#
#                                                Sentence Sentiment
# 864   Salonen added that data shows producers ' pulp...   neutral
# 2839  Salonen added that data shows producers ' pulp...  negative
#
#                                                Sentence Sentiment
# 2450  In Q1 of 2009 , the company 's result before t...   neutral
# 2850  In Q1 of 2009 , the company 's result before t...  negative
#
#                                                Sentence Sentiment
# 470   The measures result from decreased demand in t...   neutral
# 2854  The measures result from decreased demand in t...  negative
#
#                                                Sentence Sentiment
# 742   The currency effect had a 3.0 pct , or 20 mln ...  negative
# 2856  The currency effect had a 3.0 pct , or 20 mln ...   neutral
#
#                                                Sentence Sentiment
# 329   He said he has been losing five families a mon...  negative
# 2863  He said he has been losing five families a mon...   neutral
#
#                                                Sentence Sentiment
# 2533  Pretax loss totalled EUR 49.9 mn , compared to...  negative
# 2869  Pretax loss totalled EUR 49.9 mn , compared to...   neutral
#
#                                                Sentence Sentiment
# 335   At 1.33 pm , the OMX Helsinki 25 was 0.30 pct ...   neutral
# 2871  At 1.33 pm , the OMX Helsinki 25 was 0.30 pct ...  negative
#
#                                                Sentence Sentiment
# 2402  In 2009 , Stora Enso 's net loss was EUR 879.7...   neutral
# 2890  In 2009 , Stora Enso 's net loss was EUR 879.7...  negative
#
#                                                Sentence Sentiment
# 1922  30 November 2009 - Finnish office furniture ma...  negative
# 2908  30 November 2009 - Finnish office furniture ma...   neutral
#
#                                                Sentence Sentiment
# 2776  However , the orders received during the perio...   neutral
# 2925  However , the orders received during the perio...  negative
#
#                                                Sentence Sentiment
# 2035  In July-September 2009 , Konecranes ' sales de...   neutral
# 2927  In July-September 2009 , Konecranes ' sales de...  negative
#
#                                                Sentence Sentiment
# 2441  Scanfil , a systems supplier and contract manu...   neutral
# 2943  Scanfil , a systems supplier and contract manu...  negative
#
#                                                Sentence Sentiment
# 2303  The company plans to close two of the three li...   neutral
# 2953  The company plans to close two of the three li...  negative
#
#                                                Sentence Sentiment
# 1156  Qualcomm estimated a first-quarter profit betw...   neutral
# 2956  Qualcomm estimated a first-quarter profit betw...  negative
#
#                                                Sentence Sentiment
# 1398  Comparable operating profit for the quarter de...   neutral
# 2977  Comparable operating profit for the quarter de...  negative
#
#                                                Sentence Sentiment
# 2512  Sales at the unit slumped last year after the ...   neutral
# 2979  Sales at the unit slumped last year after the ...  negative
#
#                                                Sentence Sentiment
# 1097  `` Operating profit declined mainly due to the...   neutral
# 3003  `` Operating profit declined mainly due to the...  negative
#
#                                                Sentence Sentiment
# 1538  They are also upset that some of the machinery...   neutral
# 3011  They are also upset that some of the machinery...  negative
#
#                                                Sentence Sentiment
# 2990  The prosecutor is also demanding Outokumpu pay...   neutral
# 3040  The prosecutor is also demanding Outokumpu pay...  negative
#
#                                                Sentence Sentiment
# 632   The production is to be liquidated before June...   neutral
# 3062  The production is to be liquidated before June...  negative
#
#                                                Sentence Sentiment
# 2037  Operating profit , excluding non-recurring ite...  negative
# 3065  Operating profit , excluding non-recurring ite...   neutral
#
#                                                Sentence Sentiment
# 2166  Finnish Vaahto Group that provides paper-makin...  negative
# 3067  Finnish Vaahto Group that provides paper-makin...   neutral
#
#                                                Sentence Sentiment
# 575   According to Finnish petrol station chain St1 ...   neutral
# 3068  According to Finnish petrol station chain St1 ...  negative
#
#                                                Sentence Sentiment
# 2515  The company expects its net sales for the whol...  negative
# 3077  The company expects its net sales for the whol...   neutral
#
#                                                Sentence Sentiment
# 248   Talentum 's net sales in September were smalle...  negative
# 3088  Talentum 's net sales in September were smalle...   neutral
#
#                                                Sentence Sentiment
# 2541  Seven-month sales of Ragutis , which is contro...  negative
# 3094  Seven-month sales of Ragutis , which is contro...   neutral
#
#                                                Sentence Sentiment
# 961   Earnings per share ( EPS ) amounted to a loss ...   neutral
# 3102  Earnings per share ( EPS ) amounted to a loss ...  negative
#
#                                                Sentence Sentiment
# 1678  So far Norwegian Norske Skog has reduced the s...  negative
# 3127  So far Norwegian Norske Skog has reduced the s...   neutral
#
#                                                Sentence Sentiment
# 114   UPM-Kymmene Corp. , the world 's largest maker...  negative
# 3130  UPM-Kymmene Corp. , the world 's largest maker...   neutral
#
#                                          Sentence Sentiment
# 456   Sales by Seppala diminished by 6 per cent .   neutral
# 3138  Sales by Seppala diminished by 6 per cent .  negative
#
#                                                Sentence Sentiment
# 1772  UPM stock fell 3 percent to EURO 12.49 $ 17.24...   neutral
# 3141  UPM stock fell 3 percent to EURO 12.49 $ 17.24...  negative
#
#                                                Sentence Sentiment
# 1920  Finnair 's Tallinn-based subsidiary , Aero AS ...  negative
# 3155  Finnair 's Tallinn-based subsidiary , Aero AS ...   neutral
#
#                                                Sentence Sentiment
# 3025  Comparable operating profit decreased to EUR 1...   neutral
# 3183  Comparable operating profit decreased to EUR 1...  negative
#
#                                                Sentence Sentiment
# 164   The pulp production in Finnish Kemij+ñrvi will...  negative
# 3193  The pulp production in Finnish Kemij+ñrvi will...   neutral
#
#                                                Sentence Sentiment
# 2040  Furthermore , sales of new passenger cars and ...   neutral
# 3197  Furthermore , sales of new passenger cars and ...  negative
#
#                                                Sentence Sentiment
# 2780  Result before taxes decreased to nearly EUR 14...  negative
# 3221  Result before taxes decreased to nearly EUR 14...   neutral
#
#                                                Sentence Sentiment
# 83    The fair value of the company 's investment pr...   neutral
# 3223  The fair value of the company 's investment pr...  negative
#
#                                                Sentence Sentiment
# 1600  Finnish technology company Raute Corporation (...   neutral
# 3237  Finnish technology company Raute Corporation (...  negative
#
#                                                Sentence Sentiment
# 2413  Finnish Scanfil , a contract manufacturer and ...  negative
# 3241  Finnish Scanfil , a contract manufacturer and ...   neutral
#
#                                                Sentence Sentiment
# 3085  The EU Commission said earlier it had fined Th...  negative
# 3242  The EU Commission said earlier it had fined Th...   neutral
#
#                                                Sentence Sentiment
# 2136  In the reporting period , EPS stood at EUR0 .0...   neutral
# 3256  In the reporting period , EPS stood at EUR0 .0...  negative
#
#                                                Sentence Sentiment
# 846   Finnair said that the cancellation of flights ...  negative
# 3262  Finnair said that the cancellation of flights ...   neutral
#
#                                                Sentence Sentiment
# 2727  The company slipped to an operating loss of EU...  negative
# 3271  The company slipped to an operating loss of EU...   neutral
#
#                                                Sentence Sentiment
# 3079  The company serves customers in various indust...   neutral
# 3272  The company serves customers in various indust...   neutral
#
#                                                Sentence Sentiment
# 498   2009 3 February 2010 - Finland-based steel mak...  negative
# 3283  2009 3 February 2010 - Finland-based steel mak...   neutral
#
#                                                Sentence Sentiment
# 2138  Finnish shipping company Finnlines ' pretax lo...   neutral
# 3292  Finnish shipping company Finnlines ' pretax lo...  negative
#
#                                                Sentence Sentiment
# 270   Jan. 6 -- Ford is struggling in the face of sl...   neutral
# 3296  Jan. 6 -- Ford is struggling in the face of sl...  negative
#
#                                                Sentence Sentiment
# 2718  In Finland , Sampo Bank , now part of the Dans...  negative
# 3300  In Finland , Sampo Bank , now part of the Dans...   neutral
#
#                                                Sentence Sentiment
# 304   The company 's profit totaled Ls 578,100 in H1...  negative
# 3316  The company 's profit totaled Ls 578,100 in H1...   neutral
#
#                                                Sentence Sentiment
# 1869  The fair value of the company 's investment pr...  negative
# 3321  The fair value of the company 's investment pr...   neutral
#
#                                                Sentence Sentiment
# 2798  Profitability ( EBIT % ) was 13.6 % , compared...   neutral
# 3355  Profitability ( EBIT % ) was 13.6 % , compared...  negative
#
#                                                Sentence Sentiment
# 2248  In the Baltic countries , development of opera...  negative
# 3362  In the Baltic countries , development of opera...   neutral
#
#                                                Sentence Sentiment
# 904   in Finland Finnish pharmaceutical company Orio...   neutral
# 3368  in Finland Finnish pharmaceutical company Orio...  negative
#
#                                                Sentence Sentiment
# 2337  Finnish Food Workers ' Union SEL plans to hast...  negative
# 3385  Finnish Food Workers ' Union SEL plans to hast...   neutral
#
#                                                Sentence Sentiment
# 1864  Vanhanen said the strike would be `` extremely...   neutral
# 3390  Vanhanen said the strike would be `` extremely...  negative
#
#                                                Sentence Sentiment
# 84    Dealers said the share was largely hit by inve...  negative
# 3394  Dealers said the share was largely hit by inve...   neutral
#
#                                                Sentence Sentiment
# 2116  Operating profit for the 12-month period decre...   neutral
# 3403  Operating profit for the 12-month period decre...  negative
#
#                                                Sentence Sentiment
# 1802  Belarus OAO Lidskoe Pivo brewery , based in th...   neutral
# 3408  Belarus OAO Lidskoe Pivo brewery , based in th...  negative
#
#                                                Sentence Sentiment
# 1769  A high court in Finland has fined seven local ...  negative
# 3411  A high court in Finland has fined seven local ...   neutral
#
#                                                Sentence Sentiment
# 1107  The low capacity utilisation rate in steel pro...   neutral
# 3414  The low capacity utilisation rate in steel pro...  negative
#
#                                                Sentence Sentiment
# 2073  Operating loss totaled EUR 0.8 mn , compared t...  negative
# 3433  Operating loss totaled EUR 0.8 mn , compared t...   neutral
#
#                                                Sentence Sentiment
# 223   The number of bodily injury cases quadrupled i...  negative
# 3446  The number of bodily injury cases quadrupled i...   neutral
#
#                                                Sentence Sentiment
# 2236  In Finland , snow storms brought trees down on...  negative
# 3447  In Finland , snow storms brought trees down on...   neutral
#
#                                         Sentence Sentiment
# 929   Scanfil has also issued a profit warning .  negative
# 3449  Scanfil has also issued a profit warning .   neutral
#
#                                                Sentence Sentiment
# 715   The poorest index figure was given to Finnish ...  negative
# 3452  The poorest index figure was given to Finnish ...   neutral
#
#                                                Sentence Sentiment
# 3413  The contracts of the employees , 96 of whom ar...   neutral
# 3456  The contracts of the employees , 96 of whom ar...  negative
#
#                                                Sentence Sentiment
# 2008  The airline estimated that the cancellation of...  negative
# 3462  The airline estimated that the cancellation of...   neutral
#
#                                                Sentence Sentiment
# 1277  As a result , the company has decided it will ...   neutral
# 3473  As a result , the company has decided it will ...  negative
#
#                                                Sentence Sentiment
# 2755  The company 's annual loss amounted to EEK 18m...   neutral
# 3476  The company 's annual loss amounted to EEK 18m...  negative
#
#                                                Sentence Sentiment
# 2235  11 August 2010 - Finnish measuring equipment m...  negative
# 3514  11 August 2010 - Finnish measuring equipment m...   neutral
#
#                                                Sentence Sentiment
# 2686  In food trade , sales amounted to EUR320 .1 m ...  negative
# 3519  In food trade , sales amounted to EUR320 .1 m ...   neutral
#
#                                                Sentence Sentiment
# 2999  Operating loss totalled EUR 4.0 mn , compared ...   neutral
# 3529  Operating loss totalled EUR 4.0 mn , compared ...  negative
#
#                                                Sentence Sentiment
# 1763  Finnish Scanfil , a systems supplier and contr...   neutral
# 3530  Finnish Scanfil , a systems supplier and contr...  negative
#
#                                                Sentence Sentiment
# 958   The company 's previous estimate was for a low...   neutral
# 3535  The company 's previous estimate was for a low...  negative
#
#                                                Sentence Sentiment
# 1683  Operating loss totalled EUR 12.7 mn , compared...   neutral
# 3536  Operating loss totalled EUR 12.7 mn , compared...  negative
#
#                                                Sentence Sentiment
# 2193  According to Scanfil , demand for telecommunic...   neutral
# 3537  According to Scanfil , demand for telecommunic...  negative
#
#                                                Sentence Sentiment
# 1598  The stock was hit by the profit warning of Fin...   neutral
# 3538  The stock was hit by the profit warning of Fin...  negative
#
#                                                Sentence Sentiment
# 2944  Operating profit decreased to EUR 16mn from EU...   neutral
# 3553  Operating profit decreased to EUR 16mn from EU...  negative
#
#                                                Sentence Sentiment
# 1110  Finnish Bank of +àland reports its operating p...  negative
# 3558  Finnish Bank of +àland reports its operating p...   neutral
#
#                                                Sentence Sentiment
# 2158  Earnings per share ( EPS ) in 2005 decreased t...   neutral
# 3566  Earnings per share ( EPS ) in 2005 decreased t...  negative
#
#                                                Sentence Sentiment
# 2929  Cencorp 's net sales in the first quarter is e...   neutral
# 3570  Cencorp 's net sales in the first quarter is e...  negative
#
#                                                Sentence Sentiment
# 1243  The repurchases shall decrease the distributab...  negative
# 3618  The repurchases shall decrease the distributab...   neutral
#
#                                                Sentence Sentiment
# 651   `` We cut our frequency to New York last year ...  negative
# 3642  `` We cut our frequency to New York last year ...   neutral
#
#                                                Sentence Sentiment
# 3460  Consolidated operating profit from continuing ...  negative
# 3655  Consolidated operating profit from continuing ...   neutral
#
#                                                Sentence Sentiment
# 2447  In Q1 of 2009 , the company 's operating loss ...  negative
# 3670  In Q1 of 2009 , the company 's operating loss ...   neutral
#
#                                                Sentence Sentiment
# 2087  Cash flow after investments amounted to EUR45m...  negative
# 3672  Cash flow after investments amounted to EUR45m...   neutral
#
#                                                Sentence Sentiment
# 2996  The Baltimore Police and Fire Pension , which ...   neutral
# 3673  The Baltimore Police and Fire Pension , which ...  negative
#
#                                                Sentence Sentiment
# 1705  Finnair believes the strike will cause it dail...   neutral
# 3684  Finnair believes the strike will cause it dail...  negative
#
#                                                Sentence Sentiment
# 511   23 April 2010 - Finnish construction and engin...  negative
# 3689  23 April 2010 - Finnish construction and engin...   neutral
#
#                                                Sentence Sentiment
# 2917  Capacity will ease at its Seikku sawmill in Po...   neutral
# 3696  Capacity will ease at its Seikku sawmill in Po...  negative
#
#                                                Sentence Sentiment
# 221   Revenue for the quarter totaled 27.4 billion ,...  negative
# 3700  Revenue for the quarter totaled 27.4 billion ,...   neutral
#
#                                                Sentence Sentiment
# 3694  In Sweden , there is an oversupply of pharmaci...  negative
# 3701  In Sweden , there is an oversupply of pharmaci...   neutral
#
#                                                Sentence Sentiment
# 2098  20 October 2010 - Finnish environmental manage...  negative
# 3720  20 October 2010 - Finnish environmental manage...   neutral
#
#                                                Sentence Sentiment
# 2715  The period-end cash and cash equivalents total...   neutral
# 3729  The period-end cash and cash equivalents total...  negative
#
#                                                Sentence Sentiment
# 1649  Nokia shares hit 13.21 euros on Friday , down ...  negative
# 3738  Nokia shares hit 13.21 euros on Friday , down ...   neutral
#
#                                                Sentence Sentiment
# 3345  Operating profit , excluding non-recurring ite...   neutral
# 3750  Operating profit , excluding non-recurring ite...  negative
#
#                                                Sentence Sentiment
# 1693  Cramo slipped to a pretax loss of EUR 6.7 mill...  negative
# 3762  Cramo slipped to a pretax loss of EUR 6.7 mill...   neutral
#
#                                                Sentence Sentiment
# 1488  ( ADP News ) - Feb 12 , 2009 - Finnish constru...  negative
# 3765  ( ADP News ) - Feb 12 , 2009 - Finnish constru...   neutral
#
#                                                Sentence Sentiment
# 3451  UPM said the move will lower net profit by  x2...  negative
# 3768  UPM said the move will lower net profit by  x2...   neutral
#
#                                                Sentence Sentiment
# 885   Group EBIT for the first half was EUR13 .6 m U...   neutral
# 3780  Group EBIT for the first half was EUR13 .6 m U...  negative
#
#                                                Sentence Sentiment
# 1402  Finnish financial software solutions developer...   neutral
# 3782  Finnish financial software solutions developer...  negative
#
#                                                Sentence Sentiment
# 1987  ADPnews - Jul 17 , 2009 - Finland-based steel ...  negative
# 3797  ADPnews - Jul 17 , 2009 - Finland-based steel ...   neutral
#
#                                                Sentence Sentiment
# 942   The lay-offs will affect 240 people out of the...  negative
# 3803  The lay-offs will affect 240 people out of the...   neutral
#
#                                                Sentence Sentiment
# 2914  Finnish M-real 's Kyro mill is starting negoti...   neutral
# 3804  Finnish M-real 's Kyro mill is starting negoti...  negative
#
#                                                Sentence Sentiment
# 2513  Salcomp Oyj , the Finnish maker of mobile phon...   neutral
# 3810  Salcomp Oyj , the Finnish maker of mobile phon...  negative
#
#                                                Sentence Sentiment
# 381   Finnish construction company YIT is reducing t...   neutral
# 3833  Finnish construction company YIT is reducing t...  negative
#
#                                                Sentence Sentiment
# 3063  ADP News - May 29 , 2009 - Bank of America Bof...   neutral
# 3845  ADP News - May 29 , 2009 - Bank of America Bof...  negative
#
#                                                Sentence Sentiment
# 1213  The Department Store Division 's sales fell by...  negative
# 3849  The Department Store Division 's sales fell by...   neutral
#
#                                                Sentence Sentiment
# 1536  At 12.01 pm , the OMX Helsinki 25 was down 0.6...   neutral
# 3854  At 12.01 pm , the OMX Helsinki 25 was down 0.6...  negative
#
#                                                Sentence Sentiment
# 398   Acando AB ( ACANB SS ) fell 8.9 percent to 13....  negative
# 3857  Acando AB ( ACANB SS ) fell 8.9 percent to 13....   neutral
#
#                                                Sentence Sentiment
# 1992  Profit before taxes amounted to EUR 56.5 mn , ...   neutral
# 3862  Profit before taxes amounted to EUR 56.5 mn , ...  negative
#
#                                                Sentence Sentiment
# 3457  Stora Enso 's target has been cut to EUR 4.85 ...   neutral
# 3868  Stora Enso 's target has been cut to EUR 4.85 ...  negative
#
#                                                Sentence Sentiment
# 3186  Return on investment ROI was 4.1 % compared to...   neutral
# 3871  Return on investment ROI was 4.1 % compared to...  negative
#
#                                                Sentence Sentiment
# 1667  Finnish software and hardware developer Elektr...  negative
# 3873  Finnish software and hardware developer Elektr...   neutral
#
#                                                Sentence Sentiment
# 1676  Operating profit excluding non-recurring items...  negative
# 3874  Operating profit excluding non-recurring items...   neutral
#
#                                                Sentence Sentiment
# 1262  Metso estimates the need for personnel reducti...   neutral
# 3889  Metso estimates the need for personnel reducti...  negative
#
#                                                Sentence Sentiment
# 1335  As a result of these negotiations the company ...   neutral
# ...
# 5358  Return on capital employed ROCE was a negative...   neutral
#
#                                                Sentence Sentiment
# 1125  Coca-Cola was the market leader of manufacture...  negative
# 5370  Coca-Cola was the market leader of manufacture...   neutral
#
#                                                Sentence Sentiment
# 3534  According to the company , in addition to norm...   neutral
# 5377  According to the company , in addition to norm...  negative
#
#                                                Sentence Sentiment
# 2791  According to Arokarhu , some of the purchases ...   neutral
# 5378  According to Arokarhu , some of the purchases ...  negative
#
#                                                Sentence Sentiment
# 3485  Lassila & Tikanoja 's operating profit excludi...  negative
# 5384  Lassila & Tikanoja 's operating profit excludi...   neutral
#
#                                                Sentence Sentiment
# 3635  At 1411 CET , ArcelorMittal had lost 7.26 % to...   neutral
# 5404  At 1411 CET , ArcelorMittal had lost 7.26 % to...  negative
#
#                                                Sentence Sentiment
# 3648  The company said that sales in the three month...  negative
# 5414  The company said that sales in the three month...   neutral
#
#                                                Sentence Sentiment
# 391   YIT lodged counter claims against Neste Oil to...   neutral
# 5425  YIT lodged counter claims against Neste Oil to...  negative
#
#                                                Sentence Sentiment
# 1260  55 workers in +àm+Ñl will be affected by the c...  negative
# 5438  55 workers in +àm+Ñl will be affected by the c...   neutral
#
#                                                Sentence Sentiment
# 995   Finnish waste management and cleaning group La...  negative
# 5440  Finnish waste management and cleaning group La...   neutral
#
#                                                Sentence Sentiment
# 475   Operating loss increased to EUR 17mn from a lo...   neutral
# 5441  Operating loss increased to EUR 17mn from a lo...  negative
#
#                                                Sentence Sentiment
# 555   Compared with the FTSE 100 index , which rose ...  negative
# 5461  Compared with the FTSE 100 index , which rose ...   neutral
#
#                                                Sentence Sentiment
# 5232  In sales volume , Coca-Cola 's market share ha...   neutral
# 5465  In sales volume , Coca-Cola 's market share ha...  negative
#
#                                                Sentence Sentiment
# 3059  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 5471  Operating profit fell to EUR 35.4 mn from EUR ...   neutral
#
#                                                Sentence Sentiment
# 3009  On top of that , the US Commerce Department pu...  negative
# 5481  On top of that , the US Commerce Department pu...   neutral
#
#                                                Sentence Sentiment
# 3852  Net cash from operating activities was a negat...  negative
# 5485  Net cash from operating activities was a negat...   neutral
#
#                                                Sentence Sentiment
# 429   The total need for staff cuts corresponds to a...  negative
# 5486  The total need for staff cuts corresponds to a...   neutral
#
#                                                Sentence Sentiment
# 4203  Operating profit fell to EUR 23.26 mn from EUR...  negative
# 5492  Operating profit fell to EUR 23.26 mn from EUR...   neutral
#
#                                               Sentence Sentiment
# 676   In the Baltic countries , sales fell by 42.6 % .   neutral
# 5498  In the Baltic countries , sales fell by 42.6 % .  negative
#
#                                                Sentence Sentiment
# 4024  However , the company saw its net profit for t...   neutral
# 5510  However , the company saw its net profit for t...  negative
#
#                                                Sentence Sentiment
# 773   Finnish management software solutions provider...   neutral
# 5512  Finnish management software solutions provider...  negative
#
#                                                Sentence Sentiment
# 2974  ADPnews - Sep 28 , 2009 - Finnish silicon wafe...  negative
# 5515  ADPnews - Sep 28 , 2009 - Finnish silicon wafe...   neutral
#
#                                                Sentence Sentiment
# 1728  Incap Furniture is presently negotiating staff...   neutral
# 5518  Incap Furniture is presently negotiating staff...  negative
#
#                                                Sentence Sentiment
# 4292  Production levels have been agreed with produc...   neutral
# 5520  Production levels have been agreed with produc...  negative
#
#                                                Sentence Sentiment
# 1627  Diluted earnings per share ( EPS ) stood at EU...   neutral
# 5532  Diluted earnings per share ( EPS ) stood at EU...  negative
#
#                                                Sentence Sentiment
# 1696  Finnish communication electronics components s...  negative
# 5558  Finnish communication electronics components s...   neutral
#
#                                                Sentence Sentiment
# 3041  Konecranes has previously communicated an esti...  negative
# 5561  Konecranes has previously communicated an esti...   neutral
#
#                                                Sentence Sentiment
# 4694  Operating cash flow after investments totalled...   neutral
# 5564  Operating cash flow after investments totalled...  negative
#
#                                                Sentence Sentiment
# 2685  Pharmaceuticals group Orion Corp reported a fa...   neutral
# 5567  Pharmaceuticals group Orion Corp reported a fa...  negative
#
#                                                Sentence Sentiment
# 2706  Hobby Hall 's sales decrease 26 pct due to imp...   neutral
# 5569  Hobby Hall 's sales decrease 26 pct due to imp...  negative
#
#                                                Sentence Sentiment
# 172   Operating loss totalled EUR 3.2 mn , compared ...  negative
# 5571  Operating loss totalled EUR 3.2 mn , compared ...   neutral
#
#                                      Sentence Sentiment
# 2330  Subscription sales decreased slightly .  negative
# 5572  Subscription sales decreased slightly .   neutral
#
#                                                Sentence Sentiment
# 3163  Finnish sports equipment company Amer Sports s...  negative
# 5574  Finnish sports equipment company Amer Sports s...   neutral
#
#                                                Sentence Sentiment
# 4916  The total capital of funds managed by the bank...  negative
# 5583  The total capital of funds managed by the bank...   neutral
#
#                                                Sentence Sentiment
# 4763  Commission income decreased to EUR 3.8 mn , co...  negative
# 5584  Commission income decreased to EUR 3.8 mn , co...   neutral
#
#                                                Sentence Sentiment
# 5448  Finnish media group Talentum has issued a prof...   neutral
# 5592  Finnish media group Talentum has issued a prof...  negative
#
#                                                Sentence Sentiment
# 1898  However , the growth margin slowed down due to...  negative
# 5602  However , the growth margin slowed down due to...   neutral
#
#                                                Sentence Sentiment
# 5364  Kone said in court papers that the union actio...   neutral
# 5605  Kone said in court papers that the union actio...  negative
#
#                                                Sentence Sentiment
# 4117  Net sales dropped by 6 % year-on-year to EUR 1...   neutral
# 5611  Net sales dropped by 6 % year-on-year to EUR 1...  negative
#
#                                                Sentence Sentiment
# 3677  down to EUR5 .9 m H1 '09 3 August 2009 - Finni...  negative
# 5612  down to EUR5 .9 m H1 '09 3 August 2009 - Finni...   neutral
#
#                                                Sentence Sentiment
# 188   Finnish textiles and clothing group Marimekko ...   neutral
# 5614  Finnish textiles and clothing group Marimekko ...  negative
#
#                                                Sentence Sentiment
# 4290  Vaisala 's net profit for the third quarter of...   neutral
# 5623  Vaisala 's net profit for the third quarter of...  negative
#
#                                                Sentence Sentiment
# 2749  Finnish Suominen Corporation that makes wipes ...   neutral
# 5624  Finnish Suominen Corporation that makes wipes ...  negative
#
#                                                Sentence Sentiment
# 2408  The Estonian electronic components factory , E...  negative
# 5625  The Estonian electronic components factory , E...   neutral
#
#                                                Sentence Sentiment
# 2900  As a result of these transactions , the aggreg...  negative
# 5628  As a result of these transactions , the aggreg...   neutral
#
#                                                Sentence Sentiment
# 2290  Diluted earnings per share ( EPS ) declined to...   neutral
# 5629  Diluted earnings per share ( EPS ) declined to...  negative
#
#                                                Sentence Sentiment
# 2731  All the ferries had run into trouble just outs...   neutral
# 5643  All the ferries had run into trouble just outs...  negative
#
#                                                Sentence Sentiment
# 4571  Operating profit excluding non-recurring items...   neutral
# 5646  Operating profit excluding non-recurring items...  negative
#
#                                                Sentence Sentiment
# 5570  Last year , 8.3 million passengers flew the ai...   neutral
# 5648  Last year , 8.3 million passengers flew the ai...  negative
#
#                                                Sentence Sentiment
# 2782  The company reported today an operating loss o...  negative
# 5653  The company reported today an operating loss o...   neutral
#
#                                                Sentence Sentiment
# 3252  It generated an operating loss of EUR 96.3 mn ...   neutral
# 5661  It generated an operating loss of EUR 96.3 mn ...  negative
#
#                                                Sentence Sentiment
# 4307  In the first half of 2008 , the Bank 's operat...  negative
# 5662  In the first half of 2008 , the Bank 's operat...   neutral
#
#                                                Sentence Sentiment
# 2968  25 March 2011 - Finnish electronics contract m...   neutral
# 5664  25 March 2011 - Finnish electronics contract m...  negative
#
#                                                Sentence Sentiment
# 5550  The negotiation has resulted in the reduction ...  negative
# 5669  The negotiation has resulted in the reduction ...   neutral
#
#                                                Sentence Sentiment
# 2926  Net sales fell by 33 % from the third quarter ...   neutral
# 5671  Net sales fell by 33 % from the third quarter ...  negative
#
#                                                Sentence Sentiment
# 2321  Operating profit before non-recurring items wa...   neutral
# 5674  Operating profit before non-recurring items wa...  negative
#
#                                                Sentence Sentiment
# 2186  Food sales totalled EUR 323.5 mn in October 20...   neutral
# 5676  Food sales totalled EUR 323.5 mn in October 20...  negative
#
#                                                Sentence Sentiment
# 3844  In September alone , the market declined by 10...   neutral
# 5683  In September alone , the market declined by 10...  negative
#
#                                                Sentence Sentiment
# 4468  Operating result , excluding one-off items , t...  negative
# 5704  Operating result , excluding one-off items , t...   neutral
#
#                                                Sentence Sentiment
# 1316  Aspocomp has a large factory in China and a fa...   neutral
# 5713  Aspocomp has a large factory in China and a fa...  negative
#
#                                                Sentence Sentiment
# 2362  Operating profit totalled EUR 9.6 mn , down fr...   neutral
# 5725  Operating profit totalled EUR 9.6 mn , down fr...  negative
#
#                                                Sentence Sentiment
# 5472  The largest restructuring is planned for Italy...  negative
# 5749  The largest restructuring is planned for Italy...   neutral
#
#                                                Sentence Sentiment
# 1549  Operating profit totaled EUR 9.4 mn , down fro...   neutral
# 5750  Operating profit totaled EUR 9.4 mn , down fro...  negative
#                                                Sentence Sentiment
# 2209  Earnings per share EPS in 2005 decreased to EU...   neutral
# 5751  Earnings per share EPS in 2005 decreased to EU...  negative
#
#                                                Sentence Sentiment
# 5634  Net sales decreased to EUR 220.5 mn from EUR 4...  negative
# 5755  Net sales decreased to EUR 220.5 mn from EUR 4...   neutral
#
#                                                Sentence Sentiment
# 4736  Market share decreased on the route between He...  negative
# 5761  Market share decreased on the route between He...   neutral
#
#                                                Sentence Sentiment
# 4774  Finnish Suominen Flexible Packaging is cutting...   neutral
# 5762  Finnish Suominen Flexible Packaging is cutting...  negative
#
#                                                Sentence Sentiment
# 2050  HELSINKI Thomson Financial - Shares closed lit...   neutral
# 5766  HELSINKI Thomson Financial - Shares closed lit...  negative
#
#                                                Sentence Sentiment
# 473   Finnish glass technology company Glaston Oyj A...   neutral
# 5780  Finnish glass technology company Glaston Oyj A...  negative
#
#                                                Sentence Sentiment
# 3437  Profit before taxes decreased to EUR 31.6 mn f...  negative
# 5785  Profit before taxes decreased to EUR 31.6 mn f...   neutral
#
#                                                Sentence Sentiment
# 4895  Finnish business software group AffectoGenimap...  negative
# 5788  Finnish business software group AffectoGenimap...   neutral
#
#                                                Sentence Sentiment
# 2522  At this growth rate , paying off the national ...   neutral
# 5801  At this growth rate , paying off the national ...  negative
#
#                                                Sentence Sentiment
# 218   The administrators have indicated a need for 9...   neutral
# 5804  The administrators have indicated a need for 9...  negative
#
#                                                Sentence Sentiment
# 4735  Rivals say Qualcomm has fewer patents on 3G ph...  negative
# 5807  Rivals say Qualcomm has fewer patents on 3G ph...   neutral
#
#                                                Sentence Sentiment
# 1996  Sales in Finland decreased by 2.0 % , and inte...  negative
# 5812  Sales in Finland decreased by 2.0 % , and inte...   neutral
#
#                                                Sentence Sentiment
# 5422  Finnish electronics contract manufacturer Scan...   neutral
# 5821  Finnish electronics contract manufacturer Scan...  negative
#
#                                                Sentence Sentiment
# 1186  ( ADPnews ) - Oct 21 , 2009 - Finland-based IT...   neutral
# 5827  ( ADPnews ) - Oct 21 , 2009 - Finland-based IT...  negative
#
#                                                Sentence Sentiment
# 1026  Finnish developer and manufacturer of mobile p...   neutral
# 5831  Finnish developer and manufacturer of mobile p...  negative
#
#                                                Sentence Sentiment
# 2982  Operating profit fell to EUR 38.1 mn from EUR ...   neutral
# 5832  Operating profit fell to EUR 38.1 mn from EUR ...  negative
#
#                                                Sentence Sentiment
# 1860  RISING costs have forced packaging producer Hu...   neutral
# 5837  RISING costs have forced packaging producer Hu...  negative
#
#                                                Sentence Sentiment
# 186   In the building and home improvement trade , s...  negative
# 5840  In the building and home improvement trade , s...   neutral

# %%
# dropping the duplicate sentences with "neutral" sentiment
for index in duplicate_indices:
    temp = df[df['Sentence'] == df['Sentence'].loc[index]]
    dup_idx = temp[temp['Sentiment'] == 'neutral'].index[0]
    df = df.drop(index=dup_idx)


# verifying if duplicate sentences are dropped
df[df['Sentence'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Sentence, Sentiment]
# Index: []

# %%
# updated distribution of datapoints into respective class labels
print(df['Sentiment'].value_counts())

# plotting the class distribution after droping duplicates
chart = sns.countplot(x="Sentiment", data=df, palette="Set2")
axes = chart.axes
axes.set_title('Class Distribution - Updated')
axes.set_xlabel('Sentiment')
plt.show()
# Out:
# neutral     2610
# positive    1852
# negative     860
# Name: Sentiment, dtype: int64

# %%
# printing the count of null values in the dataset
df.isnull().sum()
# Out:
# Sentence     0
# Sentiment    0
# dtype: int64

# %% [markdown]
# ## Discussions needed:
# 1. Splitting the dataset into train & test before pre-processing (stop-words, punctuations, vector representations)
# 2. Class imbalance needs to be handled or not
